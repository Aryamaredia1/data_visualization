# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - Capomulin and Ramicane have the lowest mean tumor volumes, suggesting that they may be more effective at reducing tumor size compared to other drug regimens.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
import numpy as np


# Study data files
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
mouse_metadata_path = "Resources/Mouse_metadata.csv"
study_results_path = "Resources/Study_results.csv"

# Display the data table for preview
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# printing out the first few rows for mouse-metadata
print(mouse_metadata.shape)
mouse_metadata.head()
# Out:
# (249, 5)
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Same applies for study_results 
print(study_results.shape)
study_results.head()
# Out:
# (1893, 4)
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# now combining both dataframes into one and displaying it
df = pd.merge(study_results, mouse_metadata, on="Mouse ID")
df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint.
df.groupby(["Mouse ID", "Timepoint"]).size().sort_values()
# Out:
# Mouse ID  Timepoint
# a203      0            1
# q633      5            1
#           0            1
# q610      35           1
#           30           1
#                       ..
# g989      20           2
#           5            2
#           10           2
#           0            2
#           15           2
# Length: 1888, dtype: int64

# %%
# Optional: Get all the data for the duplicate mouse ID.
mask = df["Mouse ID"] == "g989"
df.loc[mask]
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
# 1195     g989         25           56.045564                 1     Propriva
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mask = df["Mouse ID"] != "g989"
df2 = df.loc[mask].reset_index(drop=True)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1880 entries, 0 to 1879
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Mouse ID            1880 non-null   object
#  1   Timepoint           1880 non-null   int64
#  2   Tumor Volume (mm3)  1880 non-null   float64
#  3   Metastatic Sites    1880 non-null   int64
#  4   Drug Regimen        1880 non-null   object
#  5   Sex                 1880 non-null   object
#  6   Age_months          1880 non-null   int64
#  7   Weight (g)          1880 non-null   int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 117.6+ KB

# %%
# Checking the number of mice in the clean DataFrame.
df2["Mouse ID"].nunique()
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
# mean, median, variance, standard deviation, and SEM of the tumor volume.
# Assemble the resulting series into a single summary DataFrame.
summary_stats = df2.groupby("Drug Regimen")["Tumor Volume (mm3)"].agg(
    Mean="mean",
    Median="median",
    Variance="var",
    Std_Dev="std",
    SEM=lambda x: x.std() / (len(x) ** 0.5)
)
summary_stats_df = pd.DataFrame(summary_stats)
print(summary_stats_df)
# Out:
#                    Mean     Median   Variance   Std_Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
df2.groupby("Drug Regimen").agg({"Tumor Volume (mm3)": ["mean", "median", "var", "std", "sem"]})
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
df2.groupby("Drug Regimen").size().sort_values(ascending=False).plot(kind="bar", title="Drug Regimen Size", ylabel="Count", color="lightblue")
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
data = df2.groupby("Drug Regimen").size().sort_values(ascending=False)
# canavs size
plt.figure(figsize=(15, 6)) 
# color of bars and alignment
plt.bar(data.index, data.values, color="#FFC0CB", align="center")
# x and y axis with titles using fonts and font size
plt.xlabel("Drug Regimen", fontfamily="Times New Roman", fontsize=17)
plt.ylabel("Count", fontfamily="Times New Roman", fontsize=17)
plt.title("Mouse/Timepoints per Drug Regimen", fontweight="bold", fontsize=16, fontfamily="Times New Roman")
plt.grid(axis="y", linestyle="--", color="gray", alpha=0.75)
plt.show()

# %%
# get mouse data 
mousedata = df2[["Mouse ID", "Sex"]].drop_duplicates()
mousedata.shape
# Out:
# (248, 2)

# %%
mousedata.head()
# Out:
#   Mouse ID     Sex
# 0     b128  Female
# 1     f932    Male
# 2     g107  Female
# 3     a457  Female
# 4     c819    Male

# %%
# find the count for each gender
mousedata.Sex.value_counts()
# Out:
# Sex
# Male      125
# Female    123
# Name: count, dtype: int64

# %%
# Generate a pie chart, using Pandas, showing the distribution of unique female versus male mice used in the study
data = mousedata.Sex.value_counts()
# Get the unique mice with their gender


# Make the pie chart
data.plot(kind="pie", title="Mouse Genders", autopct="%1.1f%%",colors=['#89cff0', '#FFC0CB'])

plt.show()

# %%
# Generate a pie chart, using pyplot, showing the distribution of unique female versus male mice used in the study
# Get the unique mice with their gender
# Make the pie chart
data = mousedata.Sex.value_counts()
plt.figure(figsize=(6, 6))
# color, titles and x/y axis customization 
plt.pie(data.values, labels=data.index, colors=["skyblue", "pink"], autopct="%1.1f%%", shadow=False, startangle=180, pctdistance=0.85)
centre_circle = plt.Circle((0,0), 0.60, fc='white')  # Adjust 0.70 for hole size
plt.gca().add_artist(centre_circle)
plt.title(f"% of Gender by Mouse in Study\n", fontweight="bold", fontsize=16, fontfamily="Times New Roman")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
df2.groupby("Mouse ID").Timepoint.max().reset_index()
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin
max_time = df2.groupby("Mouse ID").Timepoint.max().reset_index()

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
df3 = pd.merge(max_time, df2, on=["Mouse ID", "Timepoint"], how="left")
drugs = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
mask = df3["Drug Regimen"].isin(drugs)
df3 = df3.loc[mask].reset_index(drop=True)
df3
# Out:
#    Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0      a203         45           67.973419                 2    Infubinol
# 1      a251         45           65.525743                 1    Infubinol
# 2      a275         45           62.999356                 3     Ceftamin
# 3      a411         45           38.407618                 1     Ramicane
# 4      a444         45           43.047543                 0     Ramicane
# ..      ...        ...                 ...               ...          ...
# 95     y769         45           68.594745                 4     Ceftamin
# 96     y793         45           31.896238                 2    Capomulin
# 97     y865         45           64.729837                 3     Ceftamin
# 98     z578         45           30.638696                 0     Ramicane
# 99     z581         45           62.754451                 3    Infubinol
#
#        Sex  Age_months  Weight (g)
# 0   Female          20          23
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment = df3['Drug Regimen'].unique()

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []


# Calculate the IQR and quantitatively determine if there are any potential outliers.
for treatment in treatment:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    treatment_data = df3.loc[df3['Drug Regimen'] == treatment, 'Tumor Volume (mm3)']
    tumor_vol.append(treatment_data)
    # add subset
    q1 = np.percentile(treatment_data, 25)
    q3 = np.percentile(treatment_data, 75)
    iqr = q3 - q1


    # Determine outliers using upper and lower bounds
    lower_bound = q1 - (1.5 * iqr)
    upper_bound = q3 + (1.5 * iqr)
    outliers = treatment_data[(treatment_data < lower_bound) | (treatment_data > upper_bound)]
    print(f"Outliers for {treatment}: {outliers.tolist()}")
# Out:
# Outliers for Infubinol: [36.3213458]
# Outliers for Ceftamin: []
# Outliers for Ramicane: []
# Outliers for Capomulin: []

# %%
regimen = "Capomulin"

df5 = df2.loc[df2["Drug Regimen"] == regimen]
df6 = df5.groupby("Mouse ID").agg({"Tumor Volume (mm3)": "mean", "Weight (g)": "mean"}).reset_index()
df6.head()
# Out:
#   Mouse ID  Tumor Volume (mm3)  Weight (g)
# 0     b128           41.963636        22.0
# 1     b742           40.083699        21.0
# 2     f966           36.505973        17.0
# 3     g288           41.990097        19.0
# 4     g316           44.613344        22.0

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
# canvas size
plt.figure(figsize=(12, 6))
sns.boxplot(data=df3, y="Tumor Volume (mm3)", x="Drug Regimen", color="lightblue")

# Customizations

# change colors, add in reference lines, add labels/title
plt.xlabel("Drug Regimen", fontfamily="Arial", fontsize=15)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Times New Roman", fontsize=15)
plt.title("Tumor Volume by Drug", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# background grid
plt.grid(axis="y", linestyle="--", color="silver", alpha=0.75)
#plt.xlim(0,20)

# Show/Save the Graph
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
mouse = "y793"
df4 = df2.loc[df2["Mouse ID"] == mouse].sort_values(by="Timepoint", ascending=True)

# df4.plot(kind="line", x="Timepoint", y="Tumor Volume (mm3)")

# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.plot(df4.Timepoint, df4["Tumor Volume (mm3)"], color="pink", linewidth=5)

# Customizations

# color change , reference lines and x/y axis
plt.xlabel("Timepoint (days)", fontfamily="Times New Roman", fontsize=12)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Times New Roman", fontsize=12)
plt.title(f"Capomulin Treatment of Mouse: {mouse}", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

#background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# Show/Save the Graph
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
plt.figure(figsize=(12, 6))
plt.scatter(df6["Weight (g)"], df6["Tumor Volume (mm3)"], color="lightblue", edgecolor="black", s=200)



# colors, labels and title
plt.xlabel("Weight (g)", fontfamily="Times New Roman", fontsize=15)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Times New Roman", fontsize=15)
plt.title("Weight (g) vs Tumor Volume (mm3)", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
x_values = df6["Weight (g)"]
y_values = df6["Tumor Volume (mm3)"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept # these are the points/predictions
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.95x + 21.55

# %%
rvalue
# Out:
# 0.8419363424694721

# %%
# Change Canvas Size
plt.figure(figsize=(12, 6))

# Create a basic plot
plt.scatter(df6["Weight (g)"], df6["Tumor Volume (mm3)"], color="pink", edgecolor="black", s=200)
plt.plot(df6["Weight (g)"], regress_values, color="silver", linewidth=4) 


# Change colors, reference lines, labels/title
plt.xlabel("Weight (g)", fontfamily="Times New Roman", fontsize=15)
plt.ylabel("Tumor Volume (mm3)", fontfamily="Times New Roman", fontsize=15)
plt.title("Weight (g) vs Tumor Volume (mm3)", fontweight="bold", fontsize=16, fontfamily="Times New Roman")

# background grid
plt.grid(linestyle="--", color="lightgrey", alpha=0.75)

# annotate
plt.annotate(line_eq, (22, 37), fontsize=15, color="black")

plt.show()

# %%
# made the theme blue / pink as gender theme
